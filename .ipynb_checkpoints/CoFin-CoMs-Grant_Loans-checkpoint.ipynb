# %%
import pandas as pd
import numpy as np

# %%
#read data files: raw dump that includes product approval number
#
cofin_grants_loans_raw = pd.read_csv("data_files/cofin_grants_loans_raw_ 6-22-2016.csv")
cofin_grants_loans_raw
# Out:
#                  Cofinancier                        Country  \
# 0                        NaN                            NaN
# 1                     198.00                           0.00
# 2     Asian Development Bank                      ADFD,OFID
# 3                       ADFD                           ADFD
# 4                     150.00                           0.00
# 5     Asian Development Bank                 Japan,EIB,ADFD
# 6                       ADFD                           ADFD
# 7                        NaN                            NaN
# 8                       0.00                           0.00
# 9                        AFD                     France,AFD
# 10                      0.00                           0.00
# 11    Asian Development Bank                            AFD
# 12                      0.00                           0.00
# 13                       AFD                     France,AFD
# 14                      0.00                           0.00
# ...

# %%
#remove records with all blank columns (noise from lotus notes)
cofin_grants_loans_dump = cofin_grants_loans_raw.dropna(subset = ['Loan/Grant Title'] , how='all')

# %%
#cofin_grant_loans_all
cofin_grants_loans_dump.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3111 entries, 2 to 4825
# Data columns (total 50 columns):
# Cofinancier                             3111 non-null object
# Country                                 3111 non-null object
# Other Sources                           1627 non-null object
# Approval Year (Date of Approval ADB)    3111 non-null object
# Approval Year (ADB)                     3111 non-null object
# Product Approval Number                 1071 non-null object
# Approval Numbers                        3111 non-null object
# Proj No                                 1635 non-null object
# MFF Number                              64 non-null object
# Equity Number                           1 non-null float64
# Country Mnemonic                        3062 non-null object
# Loan/Grant Title                        3111 non-null object
# Department                              3111 non-null object
# Division                                2214 non-null object
# ...

# %%
cofin_grant_loans_dump
# Out:
#                  Cofinancier                        Country  \
# 2     Asian Development Bank                      ADFD,OFID
# 3                       ADFD                           ADFD
# 5     Asian Development Bank                 Japan,EIB,ADFD
# 6                       ADFD                           ADFD
# 9                        AFD                     France,AFD
# 11    Asian Development Bank                            AFD
# 13                       AFD                     France,AFD
# 15                       AFD                     France,AFD
# 17                       AFD                     France,AFD
# 19    Asian Development Bank                     France,AFD
# 22                       AIF                            AIF
# 24    Asian Development Bank                            AIF
# 26    Asian Development Bank                  Australia,AIF
# 27                       AIF                            AIF
# 29    Asian Development Bank                            AIF
# ...

# %%
#write clean dump file
cofin_grants_loans_dump.to_csv("data_files/cofin_grants_loans_dump_6-22-2016.csv")

# %%
#
#convert approval numbers to 4 characters with trailing 0's
#

#iterate and extract approval numbers
for index,row in cofin_grants_loans_dump.iterrows():

    #temporary store approval number of current row
    approval_number_orig = str(row['Approval Numbers'])

    #split approval number into array by / character
    approval_number_split =  approval_number_orig.split("/")
    
    #
    #convert each approval number to 4 characters with trailing zeros
    #
    join_numbers = [] #temporary array for converted number
    
    #itererate through each approval number in array
    for number in approval_number_split:     
        join_numbers.append(number.zfill(4))
        
        clean_approval_numbers = '/'.join(join_numbers)       
        print clean_approval_numbers
# Out:
# 2949
# 2949/8263
# 2949
# 2949/8263
# 2990
# 2990/2991
# 2990
# 2990/2991
# 3146
# 3146/3147
# 3146/3147/0084
# 3146/3147/0084/8290
# 3151
# 3151/401-2
# 3151/401-2/466-7
# 3151/401-2/466-7/8299-300
# 3151
# 3151/0401
# 3151/0401/0402
# 3151/0401/0402/0466
# 3151/0401/0402/0466/0407
# 3151/0401/0402/0466/0407/8299
# 3151/0401/0402/0466/0407/8299/8300
# 3316
# 3316/0455
# 3363
# 3363/3364
# 3363/3364/8302
# 8305
# 3083
# 3083/8276
# 3083
# 3083/8276
# 3123
# 3123/8280
# 3123
# 3123/8280
# 3161
# 3161/8286
# 3161
# 3161/8286
# 3303
# 3303/8293
# 3303
# 3303/8293
# 3310
# 3310/8294
# 3310
# 3310/8294
# 3315
# 3315/8296
# 3315
# 3315/8296
# 3339
# 3339/8297
# 3339
# 3339/8297
# 3395
# 3395/0482
# 0126
# 0126/0437
# 0126
# 0126/0437
# 0244
# 0244/0291
# 0244
# 0244/0291
# 0261
# 0261/0262
# 0261
# 0261/0262
# 0261
# 0261/0262
# 0261
# 0261/0262
# 0327
# 0327/0328
# 0327
# 0327/0328
# 0327
# 0327/0328
# 0327
# 0327/0328
# 0374
# 0374/0375
# 0374
# 0374/0375
# 0411
# 0411/0412
# 0411
# ...

# %%
cofin_grants_loans_dump['Anchor Product'] = ''
cofin_grants_loans_dump
# Out:
# /home/erik/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#                  Cofinancier                        Country  \
# 2     Asian Development Bank                      ADFD,OFID
# 3                       ADFD                           ADFD
# 5     Asian Development Bank                 Japan,EIB,ADFD
# 6                       ADFD                           ADFD
# 9                        AFD                     France,AFD
# 11    Asian Development Bank                            AFD
# 13                       AFD                     France,AFD
# 15                       AFD                     France,AFD
# ...

# %%
#extract acnchor product
for index,row in cofin_grant_loans_dump.iterrows():
    #temporary store approval number of current row
    approval_number_orig = str(row['Approval Numbers'])

    #split approval number into array by character
    approval_number_split =  approval_number_orig.split("/")
    print approval_number_split[0]
    cofin_grant_loans_dump['Anchor Product'][index] = approval_number_split[0]

cofin_grants_loans_dump
# Out:
# 2949
# 2949
# 2990
# 2990
# 3146
# 3151
# 3151
# 3316
# 3363
# 8305
# 3083
# 3083
# 3123
# 3123
# 3161
# 3161
# 3303
# 3303
# 3310
# 3310
# 3315
# 3315
# 3339
# 3339
# 3395
# 0126
# 0126
# 0244
# 0244
# 0261
# 0261
# 0261
# 0261
# 0327
# 0327
# 0327
# 0327
# 0374
# 0374
# 0411
# 0411
# 0464
# 0464
# 3250
# 3250
# 3316
# 3316
# 0042
# 0042
# 0049
# 0049
# 0049
# 0049
# 0049
# 0049
# 0049
# 0049
# 0049
# 0082
# 0082
# 0127
# 0127
# 0143
# 0143
# 0146
# 0146
# 0175
# 0175
# 0175
# 0175
# 0175
# 0175
# 0175
# 0175
# 0243
# 0243
# 0264
# 0264
# 0272
# 0272
# 0272
# 0272
# 0289
# 0289
# 0334
# 0334
# 0336
# 0336
# 0336
# 0336
# 0347
# 0347
# 0372
# 0372
# 0414
# 0414
# 0438
# 0438
# 0442
# 0442
# 0445
# 0445
# 0458
# 0458
# 0473
# 0473
# 0485
# 0485
# 0646
# 0646
# 0786
# 0786
# 1031
# 1031
# 1183
# 1183
# 1225
# 1225
# 1331
# 1331
# 1367
# 1367
# 1396
# 1396
# 1448
# 1448
# 1621
# 1621
# 1697
# 1697
# 1703
# 1703
# 1706
# 1706
# 1768
# 1768
# 1812
# 1812
# 1823
# 1823
# 2015
# 2015
# ...

# %%
cofin_grants_loans_dump[cofin_grants_loans_dump['Admin Arrangement'] == 'Collaborative']
# Out:
#      Cofinancier              Country Other Sources  \
# 3           ADFD                 ADFD          ADFD
# 6           ADFD                 ADFD          ADFD
# 15           AFD           France,AFD           AFD
# 17           AFD           France,AFD           AFD
# 78          AsIF                 AsIF          AsIF
# 80          AsIF                 AsIF          AsIF
# 130    Australia            Australia           NaN
# 136    Australia            Australia           NaN
# 166    Australia            Australia           NaN
# 172    Australia            Australia           NaN
# 279    Australia            Australia           NaN
# 304    Australia            Australia           NaN
# 312    Australia  Australia,Australia     Australia
# 400         CIDA               Canada           NaN
# 509      Denmark              Denmark           NaN
# 573         EBRD                 EBRD          EBRD
# 576         EBRD                 EBRD          EBRD
# ...

# %%
cofin_grants_loans_dump[(cofin_grants_loans_dump['Admin Arrangement'] == 'Full Administration') | (cofin_grants_loans_dump['Admin Arrangement'] == 'Partial Administration')]
# Out:
#      Cofinancier              Country Other Sources  \
# 9            AFD           France,AFD           AFD
# 13           AFD           France,AFD           AFD
# 22           AIF                  AIF           AIF
# 27           AIF                  AIF           AIF
# 30           AIF                  AIF           AIF
# 32           AIF                  AIF           AIF
# 37           AIF                  AIF           AIF
# 40           AIF                  AIF           AIF
# 43           AIF                  AIF           AIF
# 46          AIIB          P.R.C.,AIIB          AIIB
# 50          AITF                 AITF          AITF
# 53          AITF                 AITF          AITF
# 56          AITF                 AITF          AITF
# 59          AITF                 AITF          AITF
# 62          AITF                 AITF          AITF
# 65          AITF                 AITF          AITF
# 68          AITF                 AITF          AITF
# ...
