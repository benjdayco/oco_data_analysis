# %%
import pandas as pd
import numpy as np

# %%
#read data files: raw dump that includes product approval number
#
cofin_grant_loans_raw = pd.read_csv("data_files/cofin_grant_loans_all_raw_6-20-16.csv")
cofin_grant_loans_raw
# Out:
#                   Unnamed: 0                     Unnamed: 1  \
# 0                        NaN                            NaN
# 1                     198.00                           0.00
# 2     Asian Development Bank                      ADFD,OFID
# 3                       ADFD                           ADFD
# 4                     150.00                           0.00
# 5     Asian Development Bank                 Japan,EIB,ADFD
# 6                       ADFD                           ADFD
# 7                        NaN                            NaN
# 8                       0.00                           0.00
# 9                        AFD                     France,AFD
# 10                      0.00                           0.00
# 11    Asian Development Bank                            AFD
# 12                       AFD                     France,AFD
# 13                      0.00                           0.00
# 14                       AFD                     France,AFD
# ...

# %%
cofin_grant_loans = cofin_grant_loans.dropna(subset = ['Approval Numbers'] , how='all')
print cofin_grant_loans.info()
