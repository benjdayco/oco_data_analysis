# %%
import pandas as pd
import numpy as np

# %%
#read data files: raw dump that includes product approval number
#
cofin_loan_grants_full_admin_raw = pd.read_csv("data_files/cofin_grant_loans_full_admin_for_staging.csv")

# %%
print cofin_loan_grants_full_admin_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 503 entries, 0 to 502
# Data columns (total 50 columns):
# Donor                                   503 non-null object
# Unknown                                 503 non-null object
# Approval Year (Date of Approval ADB)    503 non-null int64
# Approval Year (ADB)                     503 non-null float64
# Product Approval Number                 487 non-null object
# Approval Numbers                        503 non-null object
# Proj No                                 341 non-null object
# MFF Number                              10 non-null object
# Equity Number                           1 non-null float64
# Country Mnemonic                        503 non-null object
# Loan/Grant Title                        503 non-null object
# Department                              503 non-null object
# Division                                434 non-null object
# Approval                                503 non-null object
# ...

# %%
#convert 'Approval Year (ADB)' to text
cofin_loan_grants_full_admin_raw['Approval Year (ADB)']
# Out:
# 0      2013
# 1      2014
# 2      2014
# 3      2015
# 4      2015
# 5      2015
# 6      2015
# 7      2015
# 8      2012
# 9      2011
# 10     2015
# 11     2012
# 12     2013
# 13     2013
# 14     2014
# 15     2015
# 16     2006
# 17     2006
# 18     2006
# 19     2009
# 20     2012
# 21     2008
# 22     2007
# 23     2012
# 24     2009
# 25     2009
# 26     2011
# 27     2012
# 28     2010
# 29     2013
#        ...
# 473    2015
# 474    2012
# 475    2012
# 476    2012
# 477    2013
# 478    2014
# 479    2016
# 480    2009
# 481    2011
# 482    2012
# 483    2001
# 484    2002
# 485    2001
# 486    2002
# 487    2008
# 488    2003
# 489    2004
# 490    2005
# 491    2005
# 492    2006
# 493    2015
# 494    2015
# 495    2015
# 496    2015
# 497    2014
# 498    2011
# 499    2009
# 500    2014
# 501    2014
# 502    2014
# Name: Approval Year (ADB), dtype: float64

# %%
#create separate dump files base in Administrative Arrangement values

#select Nan Values
cofin_grant_loans_admin_arrangement_null = cofin_projects[cofin_projects_raw['Admin Arrangement'].isnull()]

#select collabs
cofin_grant_loans_admin_arrangement_collab = cofin_projects.loc[cofin_projects_raw['Admin Arrangement'] == "Collaborative"]

#select full administration
cofin_grant_loans_admin_arrangement_full_admin = cofin_projects.loc[cofin_projects_raw['Admin Arrangement'] == "Full Administration"]

#select Full Administration
cofin_grant_loans_admin_arrangement_partial_admin = cofin_projects.loc[cofin_projects_raw['Admin Arrangement'] == "Partial Administration"]

cofin_projects.to_csv("data_files/cofin_grant_loans_all.csv")
cofin_grant_loans_admin_arrangement_null.to_csv("data_files/cofin_grant_loans_admin_arrangement_null.csv")
cofin_grant_loans_admin_arrangement_collab.to_csv("data_files/cofin_grant_loans_admin_arrangement_collab.csv")
cofin_grant_loans_admin_arrangement_full_admin.to_csv("data_files/cofin_grant_loans_admin_arrangement_full_admin.csv")
cofin_grant_loans_admin_arrangement_partial_admin.to_csv("data_files/cofin_grant_loans_admin_arrangement_partial_admin.csv")
# Out:
# /home/erik/anaconda2/lib/python2.7/site-packages/pandas/core/frame.py:1997: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   "DataFrame index.", UserWarning)

# %%
#copy projects dataframe
cofin_projects_anchor = cofin_projects

cofin_projects_anchor['Anchor Product'] = "1234"

for index,row in cofin_projects.iterrows():
    #temporary store approval number of current row
    approval_number_orig = str(row['Approval Numbers'])

    #split approval number into array by character
    approval_number_split =  approval_number_orig.split("/")
    cofin_projects_anchor.loc[index, 'Anchor Product'] = approval_number_split[0]
# Out:
# /home/erik/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
print cofin_projects_anchor
cofin_projects.to_csv("data_files/cofin_grant_loans_with_anchor_products.csv")
# Out:
#                        Donor  \
# 2     Asian Development Bank
# 3                       ADFD
# 7                        AFD
# 9     Asian Development Bank
# 10                       AFD
# 12    Asian Development Bank
# 14    Asian Development Bank
# 15                       AFD
# 17    Asian Development Bank
# 18                       AFD
# 20    Asian Development Bank
# 23    Asian Development Bank
# 24                       AIF
# 26    Asian Development Bank
# 27                       AIF
# 29    Asian Development Bank
# 30                       AIF
# 32    Asian Development Bank
# 33                       AIF
# 35    Asian Development Bank
# 36                       AIF
# 38    Asian Development Bank
# 39                       AIF
# 41    Asian Development Bank
# 42                       AIF
# 45    Asian Development Bank
# 46                      AITF
# 48    Asian Development Bank
# 49                      AITF
# 51    Asian Development Bank
# ...                      ...
# ...

# %%
cofin_projects_anchor_stacked = cofin_projects_anchor.set_index(['Anchor Product','Donor'])

cofin_projects_group_sorted_by_anchor = cofin_projects_anchor_stacked.sort_index()

cofin_projects_group_sorted_by_anchor
# Out:
#                                                                                  Unknown  \
# Anchor Product Donor
# 0              Asian Development Bank                                              Japan
#                Asian Development Bank                                              Japan
#                Asian Development Bank                                              Japan
#                JBIC (ODA)                                                          Japan
#                JBIC (ODA)                                                          Japan
#                JBIC (ODA)                                                          Japan
# 0016           Asian Development Bank                                        Norway,OFID
#                Asian Development Bank                                        Norway,OFID
#                NORAD                                                              Norway
# ...

# %%
cofin_projects_group_sorted_by_anchor.to_csv("data_files/cofin_projects_group_sorted_by_anchor.csv")
